# %% [markdown]
# From: https://github.com/bradleypallen/keras-quora-question-pairs/blob/master/keras-quora-question-pairs.py

# %%
from __future__ import print_function
import numpy as np
import pandas as pd
import csv, datetime, time, json
from zipfile import ZipFile
from os.path import expanduser, exists
import re
import pickle
import time
from shared_lib import vocabulary
import utils
import scipy.sparse

# %%
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Model
from keras.layers import Input, Embedding, TimeDistributed, Dense, Lambda, concatenate, Dropout, BatchNormalization
from keras.layers.embeddings import Embedding
from keras.regularizers import l2
from keras.callbacks import Callback, ModelCheckpoint
from keras.utils.data_utils import get_file
from keras import backend as K
from sklearn.model_selection import train_test_split
# Out:
# Using TensorFlow backend.

# %%
# from word embedding example provided by instructors
def pretty_timedelta(fmt="%d:%02d:%02d", since=None, until=None):
    """Pretty-print a timedelta, using the given format string."""
    since = since or time.time()
    until = until or time.time()
    delta_s = until - since
    hours, remainder = divmod(delta_s, 3600)
    minutes, seconds = divmod(remainder, 60)
    return fmt % (hours, minutes, seconds)

# %%
# Initialize global variables
#KERAS_DATASETS_DIR = expanduser('~/.keras/datasets/')
KERAS_DATASETS_DIR = 'Data/'
QUESTION_PAIRS_FILE_URL = 'Data/'
QUESTION_PAIRS_FILE = 'train_lite.df.pkl'
#GLOVE_ZIP_FILE_URL = 'http://nlp.stanford.edu/data/glove.840B.300d.zip'
#GLOVE_ZIP_FILE = 'glove.840B.300d.zip'
#GLOVE_FILE = 'glove.840B.300d.txt'
Q1_TRAINING_POS_FILE = 'q1_train_pos.npy'
Q2_TRAINING_POS_FILE = 'q2_train_pos.npy'
LABEL_TRAINING_POS_FILE = 'label_train_pos.npy'
WORD_EMBEDDING_MATRIX_POS_FILE = 'word_embedding_matrix_pos.npy'
#NB_WORDS_POS_FILE = 'nb_words.json'
MAX_NB_WORDS = 200000
V = 200000
MAX_SEQUENCE_LENGTH = 50
EMBEDDING_DIM = 300
MODEL_WEIGHTS_FILE = 'question_pairs_weights_pos.h5'
VALIDATION_SPLIT = 0.1
TEST_SPLIT = 0.1
RNG_SEED = 13371447
NB_EPOCHS = 25
#NB_EPOCHS = 1
DROPOUT = 0.1
BATCH_SIZE = 32
OPTIMIZER = 'adam'

# %%
# takes sentence and sentence POS tags, to make 1 sequence...1/2 from words and 1/2 from tags
def build_sent(q, q_pos):
    q = str(q).split()
    q_pos = str(q_pos).split()
    if len(q) > MAX_SEQUENCE_LENGTH/2:
        # cut it off
        q = q[0:MAX_SEQUENCE_LENGTH]
    else:
        # pad to max_time
        amt_to_pad = int((MAX_SEQUENCE_LENGTH/2) - len(q))
        q.extend([0] * amt_to_pad)
    if len(q_pos) > MAX_SEQUENCE_LENGTH/2:
        # cut it off
        q_pos = q_pos[0:MAX_SEQUENCE_LENGTH]
    else:
        # pad to max_time
        amt_to_pad = int((MAX_SEQUENCE_LENGTH/2) - len(q_pos))
        q_pos.extend([0] * amt_to_pad)
    
    q_final = q + q_pos
    q_final = ' '.join(str(w) for w in q_final)
    return q_final

# %%
def build_vocab(questions, V=10000):
    #token_feed = (canonicalize_word(w) for w in sentence.split() for sentence in questions)
    #token_feed = (canonicalize_word(w) for sentence in questions for w in sentence.split())
    #print (token_feed)
    
    token_feed = []
    for sentence in questions:
        for w in str(sentence).split():
            token_feed.append(utils.canonicalize_word(w))
    token_feed = set(token_feed)
    
    vocab = vocabulary.Vocabulary(token_feed, size=V)
    
    return vocab

# %%
print("Processing Questions")

print ("Reading from source File)")

question1 = []
question2 = []
is_duplicate = []
    
f = "Data/train0.df.pkl.gz"
dev = pd.read_pickle(f)
    
t0 = time.time()
train_pos = pd.DataFrame()
i = 1000
while i < 364000:
    f = "Data/train"+str(i)+".df.pkl.gz"
    print("Starting ", f, i, i+1000, pretty_timedelta(since=t0))
    x = pd.read_pickle(f)
    train_pos = pd.concat([train_pos, x])
    print("Finished ", f, i, i+1000, pretty_timedelta(since=t0))
    i += 1000
    if i == 26000:
        i = 27000 # skip bad file

    
    print (type(train_pos))
# Out:
# Processing Questions
# Reading from source File)
# Starting  Data/train1000.df.pkl.gz 1000 2000 0:00:00
# Finished  Data/train1000.df.pkl.gz 1000 2000 0:00:00
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train2000.df.pkl.gz 2000 3000 0:00:00
# Finished  Data/train2000.df.pkl.gz 2000 3000 0:00:00
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train3000.df.pkl.gz 3000 4000 0:00:00
# Finished  Data/train3000.df.pkl.gz 3000 4000 0:00:00
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train4000.df.pkl.gz 4000 5000 0:00:00
# Finished  Data/train4000.df.pkl.gz 4000 5000 0:00:00
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train5000.df.pkl.gz 5000 6000 0:00:00
# Finished  Data/train5000.df.pkl.gz 5000 6000 0:00:00
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train6000.df.pkl.gz 6000 7000 0:00:00
# Finished  Data/train6000.df.pkl.gz 6000 7000 0:00:00
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train7000.df.pkl.gz 7000 8000 0:00:00
# Finished  Data/train7000.df.pkl.gz 7000 8000 0:00:00
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train8000.df.pkl.gz 8000 9000 0:00:00
# Finished  Data/train8000.df.pkl.gz 8000 9000 0:00:00
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train9000.df.pkl.gz 9000 10000 0:00:00
# Finished  Data/train9000.df.pkl.gz 9000 10000 0:00:00
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train10000.df.pkl.gz 10000 11000 0:00:00
# Finished  Data/train10000.df.pkl.gz 10000 11000 0:00:00
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train11000.df.pkl.gz 11000 12000 0:00:00
# Finished  Data/train11000.df.pkl.gz 11000 12000 0:00:00
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train12000.df.pkl.gz 12000 13000 0:00:00
# Finished  Data/train12000.df.pkl.gz 12000 13000 0:00:00
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train13000.df.pkl.gz 13000 14000 0:00:00
# Finished  Data/train13000.df.pkl.gz 13000 14000 0:00:00
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train14000.df.pkl.gz 14000 15000 0:00:00
# Finished  Data/train14000.df.pkl.gz 14000 15000 0:00:00
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train15000.df.pkl.gz 15000 16000 0:00:00
# Finished  Data/train15000.df.pkl.gz 15000 16000 0:00:00
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train16000.df.pkl.gz 16000 17000 0:00:00
# Finished  Data/train16000.df.pkl.gz 16000 17000 0:00:00
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train17000.df.pkl.gz 17000 18000 0:00:00
# Finished  Data/train17000.df.pkl.gz 17000 18000 0:00:00
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train18000.df.pkl.gz 18000 19000 0:00:00
# Finished  Data/train18000.df.pkl.gz 18000 19000 0:00:00
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train19000.df.pkl.gz 19000 20000 0:00:00
# Finished  Data/train19000.df.pkl.gz 19000 20000 0:00:00
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train20000.df.pkl.gz 20000 21000 0:00:00
# Finished  Data/train20000.df.pkl.gz 20000 21000 0:00:00
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train21000.df.pkl.gz 21000 22000 0:00:00
# Finished  Data/train21000.df.pkl.gz 21000 22000 0:00:00
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train22000.df.pkl.gz 22000 23000 0:00:00
# Finished  Data/train22000.df.pkl.gz 22000 23000 0:00:00
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train23000.df.pkl.gz 23000 24000 0:00:00
# Finished  Data/train23000.df.pkl.gz 23000 24000 0:00:00
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train24000.df.pkl.gz 24000 25000 0:00:00
# Finished  Data/train24000.df.pkl.gz 24000 25000 0:00:00
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train25000.df.pkl.gz 25000 26000 0:00:00
# Finished  Data/train25000.df.pkl.gz 25000 26000 0:00:00
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train27000.df.pkl.gz 27000 28000 0:00:00
# Finished  Data/train27000.df.pkl.gz 27000 28000 0:00:00
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train28000.df.pkl.gz 28000 29000 0:00:00
# Finished  Data/train28000.df.pkl.gz 28000 29000 0:00:00
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train29000.df.pkl.gz 29000 30000 0:00:00
# Finished  Data/train29000.df.pkl.gz 29000 30000 0:00:00
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train30000.df.pkl.gz 30000 31000 0:00:00
# Finished  Data/train30000.df.pkl.gz 30000 31000 0:00:00
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train31000.df.pkl.gz 31000 32000 0:00:00
# Finished  Data/train31000.df.pkl.gz 31000 32000 0:00:00
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train32000.df.pkl.gz 32000 33000 0:00:00
# Finished  Data/train32000.df.pkl.gz 32000 33000 0:00:00
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train33000.df.pkl.gz 33000 34000 0:00:00
# Finished  Data/train33000.df.pkl.gz 33000 34000 0:00:00
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train34000.df.pkl.gz 34000 35000 0:00:00
# Finished  Data/train34000.df.pkl.gz 34000 35000 0:00:00
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train35000.df.pkl.gz 35000 36000 0:00:00
# Finished  Data/train35000.df.pkl.gz 35000 36000 0:00:00
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train36000.df.pkl.gz 36000 37000 0:00:00
# Finished  Data/train36000.df.pkl.gz 36000 37000 0:00:00
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train37000.df.pkl.gz 37000 38000 0:00:00
# Finished  Data/train37000.df.pkl.gz 37000 38000 0:00:00
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train38000.df.pkl.gz 38000 39000 0:00:00
# Finished  Data/train38000.df.pkl.gz 38000 39000 0:00:00
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train39000.df.pkl.gz 39000 40000 0:00:00
# Finished  Data/train39000.df.pkl.gz 39000 40000 0:00:00
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train40000.df.pkl.gz 40000 41000 0:00:00
# Finished  Data/train40000.df.pkl.gz 40000 41000 0:00:00
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train41000.df.pkl.gz 41000 42000 0:00:00
# Finished  Data/train41000.df.pkl.gz 41000 42000 0:00:00
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train42000.df.pkl.gz 42000 43000 0:00:00
# Finished  Data/train42000.df.pkl.gz 42000 43000 0:00:00
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train43000.df.pkl.gz 43000 44000 0:00:00
# Finished  Data/train43000.df.pkl.gz 43000 44000 0:00:00
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train44000.df.pkl.gz 44000 45000 0:00:00
# Finished  Data/train44000.df.pkl.gz 44000 45000 0:00:00
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train45000.df.pkl.gz 45000 46000 0:00:00
# Finished  Data/train45000.df.pkl.gz 45000 46000 0:00:00
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train46000.df.pkl.gz 46000 47000 0:00:00
# Finished  Data/train46000.df.pkl.gz 46000 47000 0:00:00
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train47000.df.pkl.gz 47000 48000 0:00:00
# Finished  Data/train47000.df.pkl.gz 47000 48000 0:00:00
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train48000.df.pkl.gz 48000 49000 0:00:00
# Finished  Data/train48000.df.pkl.gz 48000 49000 0:00:00
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train49000.df.pkl.gz 49000 50000 0:00:00
# Finished  Data/train49000.df.pkl.gz 49000 50000 0:00:00
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train50000.df.pkl.gz 50000 51000 0:00:00
# Finished  Data/train50000.df.pkl.gz 50000 51000 0:00:00
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train51000.df.pkl.gz 51000 52000 0:00:00
# Finished  Data/train51000.df.pkl.gz 51000 52000 0:00:00
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train52000.df.pkl.gz 52000 53000 0:00:00
# Finished  Data/train52000.df.pkl.gz 52000 53000 0:00:00
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train53000.df.pkl.gz 53000 54000 0:00:00
# Finished  Data/train53000.df.pkl.gz 53000 54000 0:00:00
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train54000.df.pkl.gz 54000 55000 0:00:00
# Finished  Data/train54000.df.pkl.gz 54000 55000 0:00:00
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train55000.df.pkl.gz 55000 56000 0:00:00
# Finished  Data/train55000.df.pkl.gz 55000 56000 0:00:00
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train56000.df.pkl.gz 56000 57000 0:00:00
# Finished  Data/train56000.df.pkl.gz 56000 57000 0:00:00
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train57000.df.pkl.gz 57000 58000 0:00:00
# Finished  Data/train57000.df.pkl.gz 57000 58000 0:00:00
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train58000.df.pkl.gz 58000 59000 0:00:00
# Finished  Data/train58000.df.pkl.gz 58000 59000 0:00:00
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train59000.df.pkl.gz 59000 60000 0:00:00
# Finished  Data/train59000.df.pkl.gz 59000 60000 0:00:01
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train60000.df.pkl.gz 60000 61000 0:00:01
# Finished  Data/train60000.df.pkl.gz 60000 61000 0:00:01
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train61000.df.pkl.gz 61000 62000 0:00:01
# Finished  Data/train61000.df.pkl.gz 61000 62000 0:00:01
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train62000.df.pkl.gz 62000 63000 0:00:01
# Finished  Data/train62000.df.pkl.gz 62000 63000 0:00:01
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train63000.df.pkl.gz 63000 64000 0:00:01
# Finished  Data/train63000.df.pkl.gz 63000 64000 0:00:01
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train64000.df.pkl.gz 64000 65000 0:00:01
# Finished  Data/train64000.df.pkl.gz 64000 65000 0:00:01
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train65000.df.pkl.gz 65000 66000 0:00:01
# Finished  Data/train65000.df.pkl.gz 65000 66000 0:00:01
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train66000.df.pkl.gz 66000 67000 0:00:01
# Finished  Data/train66000.df.pkl.gz 66000 67000 0:00:01
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train67000.df.pkl.gz 67000 68000 0:00:01
# Finished  Data/train67000.df.pkl.gz 67000 68000 0:00:01
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train68000.df.pkl.gz 68000 69000 0:00:01
# Finished  Data/train68000.df.pkl.gz 68000 69000 0:00:01
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train69000.df.pkl.gz 69000 70000 0:00:01
# Finished  Data/train69000.df.pkl.gz 69000 70000 0:00:01
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train70000.df.pkl.gz 70000 71000 0:00:01
# Finished  Data/train70000.df.pkl.gz 70000 71000 0:00:01
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train71000.df.pkl.gz 71000 72000 0:00:01
# Finished  Data/train71000.df.pkl.gz 71000 72000 0:00:01
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train72000.df.pkl.gz 72000 73000 0:00:01
# Finished  Data/train72000.df.pkl.gz 72000 73000 0:00:01
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train73000.df.pkl.gz 73000 74000 0:00:01
# Finished  Data/train73000.df.pkl.gz 73000 74000 0:00:01
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train74000.df.pkl.gz 74000 75000 0:00:01
# Finished  Data/train74000.df.pkl.gz 74000 75000 0:00:01
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train75000.df.pkl.gz 75000 76000 0:00:01
# Finished  Data/train75000.df.pkl.gz 75000 76000 0:00:01
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train76000.df.pkl.gz 76000 77000 0:00:01
# Finished  Data/train76000.df.pkl.gz 76000 77000 0:00:01
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train77000.df.pkl.gz 77000 78000 0:00:01
# Finished  Data/train77000.df.pkl.gz 77000 78000 0:00:01
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train78000.df.pkl.gz 78000 79000 0:00:01
# Finished  Data/train78000.df.pkl.gz 78000 79000 0:00:01
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train79000.df.pkl.gz 79000 80000 0:00:01
# Finished  Data/train79000.df.pkl.gz 79000 80000 0:00:01
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train80000.df.pkl.gz 80000 81000 0:00:01
# Finished  Data/train80000.df.pkl.gz 80000 81000 0:00:01
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train81000.df.pkl.gz 81000 82000 0:00:01
# Finished  Data/train81000.df.pkl.gz 81000 82000 0:00:01
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train82000.df.pkl.gz 82000 83000 0:00:01
# Finished  Data/train82000.df.pkl.gz 82000 83000 0:00:01
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train83000.df.pkl.gz 83000 84000 0:00:01
# Finished  Data/train83000.df.pkl.gz 83000 84000 0:00:01
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train84000.df.pkl.gz 84000 85000 0:00:01
# Finished  Data/train84000.df.pkl.gz 84000 85000 0:00:01
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train85000.df.pkl.gz 85000 86000 0:00:01
# Finished  Data/train85000.df.pkl.gz 85000 86000 0:00:01
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train86000.df.pkl.gz 86000 87000 0:00:01
# Finished  Data/train86000.df.pkl.gz 86000 87000 0:00:02
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train87000.df.pkl.gz 87000 88000 0:00:02
# Finished  Data/train87000.df.pkl.gz 87000 88000 0:00:02
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train88000.df.pkl.gz 88000 89000 0:00:02
# Finished  Data/train88000.df.pkl.gz 88000 89000 0:00:02
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train89000.df.pkl.gz 89000 90000 0:00:02
# Finished  Data/train89000.df.pkl.gz 89000 90000 0:00:02
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train90000.df.pkl.gz 90000 91000 0:00:02
# Finished  Data/train90000.df.pkl.gz 90000 91000 0:00:02
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train91000.df.pkl.gz 91000 92000 0:00:02
# Finished  Data/train91000.df.pkl.gz 91000 92000 0:00:02
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train92000.df.pkl.gz 92000 93000 0:00:02
# Finished  Data/train92000.df.pkl.gz 92000 93000 0:00:02
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train93000.df.pkl.gz 93000 94000 0:00:02
# Finished  Data/train93000.df.pkl.gz 93000 94000 0:00:02
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train94000.df.pkl.gz 94000 95000 0:00:02
# Finished  Data/train94000.df.pkl.gz 94000 95000 0:00:02
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train95000.df.pkl.gz 95000 96000 0:00:02
# Finished  Data/train95000.df.pkl.gz 95000 96000 0:00:02
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train96000.df.pkl.gz 96000 97000 0:00:02
# Finished  Data/train96000.df.pkl.gz 96000 97000 0:00:02
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train97000.df.pkl.gz 97000 98000 0:00:02
# Finished  Data/train97000.df.pkl.gz 97000 98000 0:00:02
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train98000.df.pkl.gz 98000 99000 0:00:02
# Finished  Data/train98000.df.pkl.gz 98000 99000 0:00:02
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train99000.df.pkl.gz 99000 100000 0:00:02
# Finished  Data/train99000.df.pkl.gz 99000 100000 0:00:02
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train100000.df.pkl.gz 100000 101000 0:00:02
# Finished  Data/train100000.df.pkl.gz 100000 101000 0:00:02
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train101000.df.pkl.gz 101000 102000 0:00:02
# Finished  Data/train101000.df.pkl.gz 101000 102000 0:00:02
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train102000.df.pkl.gz 102000 103000 0:00:02
# Finished  Data/train102000.df.pkl.gz 102000 103000 0:00:02
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train103000.df.pkl.gz 103000 104000 0:00:02
# Finished  Data/train103000.df.pkl.gz 103000 104000 0:00:02
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train104000.df.pkl.gz 104000 105000 0:00:02
# Finished  Data/train104000.df.pkl.gz 104000 105000 0:00:02
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train105000.df.pkl.gz 105000 106000 0:00:02
# Finished  Data/train105000.df.pkl.gz 105000 106000 0:00:02
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train106000.df.pkl.gz 106000 107000 0:00:02
# Finished  Data/train106000.df.pkl.gz 106000 107000 0:00:02
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train107000.df.pkl.gz 107000 108000 0:00:02
# Finished  Data/train107000.df.pkl.gz 107000 108000 0:00:02
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train108000.df.pkl.gz 108000 109000 0:00:02
# Finished  Data/train108000.df.pkl.gz 108000 109000 0:00:03
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train109000.df.pkl.gz 109000 110000 0:00:03
# Finished  Data/train109000.df.pkl.gz 109000 110000 0:00:03
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train350000.df.pkl.gz 350000 351000 0:00:27
# Finished  Data/train350000.df.pkl.gz 350000 351000 0:00:27
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train351000.df.pkl.gz 351000 352000 0:00:27
# Finished  Data/train351000.df.pkl.gz 351000 352000 0:00:28
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train352000.df.pkl.gz 352000 353000 0:00:28
# Finished  Data/train352000.df.pkl.gz 352000 353000 0:00:28
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train353000.df.pkl.gz 353000 354000 0:00:28
# Finished  Data/train353000.df.pkl.gz 353000 354000 0:00:28
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train354000.df.pkl.gz 354000 355000 0:00:28
# Finished  Data/train354000.df.pkl.gz 354000 355000 0:00:28
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train355000.df.pkl.gz 355000 356000 0:00:28
# Finished  Data/train355000.df.pkl.gz 355000 356000 0:00:28
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train356000.df.pkl.gz 356000 357000 0:00:28
# Finished  Data/train356000.df.pkl.gz 356000 357000 0:00:28
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train357000.df.pkl.gz 357000 358000 0:00:28
# Finished  Data/train357000.df.pkl.gz 357000 358000 0:00:29
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train358000.df.pkl.gz 358000 359000 0:00:29
# Finished  Data/train358000.df.pkl.gz 358000 359000 0:00:29
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train359000.df.pkl.gz 359000 360000 0:00:29
# Finished  Data/train359000.df.pkl.gz 359000 360000 0:00:29
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train360000.df.pkl.gz 360000 361000 0:00:29
# Finished  Data/train360000.df.pkl.gz 360000 361000 0:00:29
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train361000.df.pkl.gz 361000 362000 0:00:29
# Finished  Data/train361000.df.pkl.gz 361000 362000 0:00:29
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train362000.df.pkl.gz 362000 363000 0:00:29
# Finished  Data/train362000.df.pkl.gz 362000 363000 0:00:29
# <class 'pandas.core.frame.DataFrame'>
# Starting  Data/train363000.df.pkl.gz 363000 364000 0:00:29
# Finished  Data/train363000.df.pkl.gz 363000 364000 0:00:30
# <class 'pandas.core.frame.DataFrame'>

# %%
print ("Build  Question Pairs with POS, maximizing sequence length to 50")

question1 = []
question2 = []
is_duplicate = []

for index, row in train_pos.iterrows():
    q1=row["question1"]
    q1_pos = row["question1_pos"]
    q2=row["question2"]
    q2_pos = row["question2_pos"]
    question1.append(build_sent(q1,q1_pos))
    question2.append(build_sent(q2,q2_pos))
    
    is_duplicate.append(row['is_duplicate'])

print('Question pairs: %d' % len(question1))
# Out:
# Build  Question Pairs with POS, maximizing sequence length to 50
# Question pairs: 361861

# %%
print ("Build Tokenized Word Index")
questions = question1 + question2
tokenizer = Tokenizer(num_words=MAX_NB_WORDS)
tokenizer.fit_on_texts(questions)
question1_word_sequences = tokenizer.texts_to_sequences(question1)
question2_word_sequences = tokenizer.texts_to_sequences(question2)
word_index = tokenizer.word_index

print("Words in index: %d" % len(word_index))

# alternative here would be to use sents_to_tokens from vocab
# Out:
# Build Tokenized Word Index
# Words in index: 90882

# %%
print (len(word_index))
print(dict(list(word_index.items())[0:2]))
print ("Build Vocab and token_ids")
vocab = list(word_index.keys())
token_ids = list(word_index.values())
print (len(vocab))
print (vocab[50881])
V = len(token_ids) + 1
print (len(token_ids))
print (token_ids[50881])

#print "Sample ids: " + str(word_index[:5])
# Out:
# 90882
# {'ruffle': 54290, '1453': 59775}
# Build Vocab and token_ids
# 90882
# chiplun
# 90882
# 49113

# %%
def cooccurrence_matrix(token_ids, Vsize, K=2):
    # We'll use this as an "accumulator" matrix
    C = scipy.sparse.csc_matrix((Vsize,Vsize), dtype=np.float32)
    print (C.shape)

    for k in range(1, K+1):
        print (u"Counting pairs (i, i \u00B1 %d) ..." % k)
        i = token_ids[:-k]  # current word
        j = token_ids[k:]   # k words ahead
        data = (np.ones_like(i), (i,j))  # values, indices
        Ck_plus = scipy.sparse.coo_matrix(data, shape=C.shape, dtype=np.float32)
        Ck_plus = scipy.sparse.csc_matrix(Ck_plus)
        Ck_minus = Ck_plus.T  # Consider k words behind
        C += Ck_plus + Ck_minus

    print ("Co-occurrence matrix: %d words x %d words" % (C.shape))
    print ("  %.02g nonzero elements" % (C.nnz))
    return C

# %%
kw=1
for k in range(1, kw+1):
    i = token_ids[:-k]  # current word
    j = token_ids[k:]   # k words ahead

# %%
k = 1
t0 = time.time()
C = cooccurrence_matrix(token_ids, V, K=k)
print ("Computed Co-occurrence matrix in %s" % utils.pretty_timedelta(since=t0), t0)
# Out:
# (90883, 90883)
# Counting pairs (i, i ± 1) ...
# Co-occurrence matrix: 90883 words x 90883 words
#   1.8e+05 nonzero elements
# Computed Co-occurrence matrix in 0:00:00 1502909650.3687503

# %%
def PPMI(C):
    """Tranform a counts matrix to PPMI.
    
    Args:
      C: scipy.sparse.csc_matrix of counts C_ij
    
    Returns:
      (scipy.sparse.csc_matrix) PPMI(C) as defined above
    """
    Z = float(C.sum())  # total counts
    # sum each column (along rows)
    Zc = np.array(C.sum(axis=0), dtype=np.float64).flatten()
    # sum each row (along columns)
    Zr = np.array(C.sum(axis=1), dtype=np.float64).flatten()
    
    # Get indices of relevant elements
    ii, jj = C.nonzero()  # row, column indices
    Cij = np.array(C[ii,jj], dtype=np.float64).flatten()
    
    ##
    # PMI equation
    pmi = np.log(Cij * Z / (Zr[ii] * Zc[jj]))
    ##
    # Truncate to positive only
    ppmi = np.maximum(0, pmi)  # take positive only
    
    # Re-format as sparse matrix
    ret = scipy.sparse.csc_matrix((ppmi, (ii,jj)), shape=C.shape,
                                  dtype=np.float64)
    ret.eliminate_zeros()  # remove zeros
    return ret

# %%
from sklearn.decomposition import TruncatedSVD
def SVD(X, d=100):
    """Returns word vectors from SVD.
    
    Args:
      X: m x n matrix
      d: word vector dimension
      
    Returns:
      Wv : m x d matrix, each row is a word vector.
    """
    transformer = TruncatedSVD(n_components=d, random_state=1)
    Wv = transformer.fit_transform(X)
    # Normalize to unit length
    Wv = Wv / np.linalg.norm(Wv, axis=1).reshape([-1,1])
    return Wv, transformer.explained_variance_

# %%
C_ppmi = PPMI(C)
print ("Computed PPMI in %s" % utils.pretty_timedelta(since=t0),t0)
word_embedding_matrix, _ = SVD(C_ppmi, d=EMBEDDING_DIM)
print ("Computed SVD in %s" % utils.pretty_timedelta(since=t0))
print('Shape of embedding matrix:', word_embedding_matrix.shape)
# Out:
# Computed PPMI in 0:00:02 1502909650.3687503
# Computed SVD in 0:00:25
# Shape of embedding matrix: (90883, 300)

# %%
# Prepare training data tensors
q1_data = pad_sequences(question1_word_sequences, maxlen=MAX_SEQUENCE_LENGTH)
q2_data = pad_sequences(question2_word_sequences, maxlen=MAX_SEQUENCE_LENGTH)
labels = np.array(is_duplicate, dtype=int)
print('Shape of question1 data tensor:', q1_data.shape)
print('Shape of question2 data tensor:', q2_data.shape)
print('Shape of label tensor:', labels.shape)
# Out:
# Shape of question1 data tensor: (361861, 50)
# Shape of question2 data tensor: (361861, 50)
# Shape of label tensor: (361861,)

# %%
# Partition the dataset into train and test sets
X = np.stack((q1_data, q2_data), axis=1)
y = labels
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=TEST_SPLIT, random_state=RNG_SEED)
Q1_train = X_train[:,0]
Q2_train = X_train[:,1]
Q1_test = X_test[:,0]
Q2_test = X_test[:,1]

# %%
# Define the model
question1 = Input(shape=(MAX_SEQUENCE_LENGTH,))
question2 = Input(shape=(MAX_SEQUENCE_LENGTH,))

q1 = Embedding(V, 
                 EMBEDDING_DIM, 
                 weights=[word_embedding_matrix], 
                 input_length=MAX_SEQUENCE_LENGTH, 
                 trainable=False)(question1)
#print ("q1 shape:", q1.shape)
q1 = TimeDistributed(Dense(EMBEDDING_DIM, activation='relu'))(q1)
#print ("q1 shape:", q1.shape)
q1 = Lambda(lambda x: K.max(x, axis=1), output_shape=(EMBEDDING_DIM, ))(q1)
#print ("q1 shape:", q1.shape)
q2 = Embedding(V, 
                 EMBEDDING_DIM, 
                 weights=[word_embedding_matrix], 
                 input_length=MAX_SEQUENCE_LENGTH, 
                 trainable=False)(question2)
q2 = TimeDistributed(Dense(EMBEDDING_DIM, activation='relu'))(q2)
q2 = Lambda(lambda x: K.max(x, axis=1), output_shape=(EMBEDDING_DIM, ))(q2)

merged = concatenate([q1,q2])
# print(merged.shape)
merged = Dense(200, activation='relu')(merged)
# print(merged.shape)
merged = Dropout(DROPOUT)(merged)
merged = BatchNormalization()(merged)
merged = Dense(200, activation='relu')(merged)
merged = Dropout(DROPOUT)(merged)
merged = BatchNormalization()(merged)
merged = Dense(200, activation='relu')(merged)
merged = Dropout(DROPOUT)(merged)
merged = BatchNormalization()(merged)
merged = Dense(200, activation='relu')(merged)
merged = Dropout(DROPOUT)(merged)
merged = BatchNormalization()(merged)

is_duplicate = Dense(1, activation='sigmoid')(merged)

model = Model(inputs=[question1,question2], outputs=is_duplicate)
model.compile(loss='binary_crossentropy', optimizer=OPTIMIZER, metrics=['accuracy'])

# %%
# Train the model, checkpointing weights with best validation accuracy
print("Starting training at", datetime.datetime.now())
t0 = time.time()
callbacks = [ModelCheckpoint(MODEL_WEIGHTS_FILE, monitor='val_acc', save_best_only=True)]
history = model.fit([Q1_train, Q2_train],
                    y_train,
                    epochs=NB_EPOCHS,
                    validation_split=VALIDATION_SPLIT,
                    verbose=2,
                    batch_size=BATCH_SIZE,
                    callbacks=callbacks)
t1 = time.time()
print("Training ended at", datetime.datetime.now())
print("Minutes elapsed: %f" % ((t1 - t0) / 60.))
# Out:
