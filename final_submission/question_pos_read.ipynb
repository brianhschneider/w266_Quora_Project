# %%
import numpy as np     # support for large data structures
import pandas as pd    # data structure support
import time

# %%
def pretty_timedelta(fmt="%d:%02d:%02d", since=None, until=None):
    """Pretty-print a timedelta, using the given format string."""
    since = since or time.time()
    until = until or time.time()
    delta_s = until - since
    hours, remainder = divmod(delta_s, 3600)
    minutes, seconds = divmod(remainder, 60)
    return fmt % (hours, minutes, seconds)

# %%
f = "Data/train_lite0.df.pkl.gz"
train_lite = pd.read_pickle(f)

# %%
t0 = time.time()
i = 1000
while True:
    f = "Data/train_lite"+str(i)+".df.pkl.gz"
    print("Starting ", f, i, i+1000, pretty_timedelta(since=t0))
    x = pd.read_pickle(f)
    train_lite = pd.concat([train_lite, x])
    print("Finished ", f, i, i+1000, pretty_timedelta(since=t0))
    i += 1000
# Out:
# Starting  Data/train_lite1000.df.pkl.gz 1000 2000 0:00:00
# Finished  Data/train_lite1000.df.pkl.gz 1000 2000 0:00:00
# Starting  Data/train_lite2000.df.pkl.gz 2000 3000 0:00:00
# Finished  Data/train_lite2000.df.pkl.gz 2000 3000 0:00:00
# Starting  Data/train_lite3000.df.pkl.gz 3000 4000 0:00:00
# Finished  Data/train_lite3000.df.pkl.gz 3000 4000 0:00:00
# Starting  Data/train_lite4000.df.pkl.gz 4000 5000 0:00:00
# Finished  Data/train_lite4000.df.pkl.gz 4000 5000 0:00:00
# Starting  Data/train_lite5000.df.pkl.gz 5000 6000 0:00:00
# Finished  Data/train_lite5000.df.pkl.gz 5000 6000 0:00:00
# Starting  Data/train_lite6000.df.pkl.gz 6000 7000 0:00:00
# Finished  Data/train_lite6000.df.pkl.gz 6000 7000 0:00:00
# Starting  Data/train_lite7000.df.pkl.gz 7000 8000 0:00:00
# Finished  Data/train_lite7000.df.pkl.gz 7000 8000 0:00:00
# Starting  Data/train_lite8000.df.pkl.gz 8000 9000 0:00:00
# Finished  Data/train_lite8000.df.pkl.gz 8000 9000 0:00:00
# Starting  Data/train_lite9000.df.pkl.gz 9000 10000 0:00:00
# Finished  Data/train_lite9000.df.pkl.gz 9000 10000 0:00:00
# Starting  Data/train_lite10000.df.pkl.gz 10000 11000 0:00:00
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/anaconda2/envs/py3/lib/python3.5/site-packages/pandas/io/pickle.py in try_read(path, encoding)
#      82         try:
# ---> 83             return read_wrapper(lambda f: pkl.load(f))
#      84         except Exception:
#
# ~/anaconda2/envs/py3/lib/python3.5/site-packages/pandas/io/pickle.py in read_wrapper(func)
#      65                             compression=inferred_compression,
# ---> 66                             is_text=False)
#      67         try:
#
# ~/anaconda2/envs/py3/lib/python3.5/site-packages/pandas/io/common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     331             if is_path:
# --> 332                 f = gzip.open(path_or_buf, mode)
#     333             else:
#
# ~/anaconda2/envs/py3/lib/python3.5/gzip.py in open(filename, mode, compresslevel, encoding, errors, newline)
#      52     if isinstance(filename, (str, bytes)):
# ---> 53         binary_file = GzipFile(filename, gz_mode, compresslevel)
#      54     elif hasattr(filename, "read") or hasattr(filename, "write"):
#
# ~/anaconda2/envs/py3/lib/python3.5/gzip.py in __init__(self, filename, mode, compresslevel, fileobj, mtime)
#     162         if fileobj is None:
# --> 163             fileobj = self.myfileobj = builtins.open(filename, mode or 'rb')
#     164         if filename is None:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Data/train_lite10000.df.pkl.gz'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# ~/anaconda2/envs/py3/lib/python3.5/site-packages/pandas/io/pickle.py in try_read(path, encoding)
#      87                 return read_wrapper(
# ---> 88                     lambda f: pc.load(f, encoding=encoding, compat=False))
#      89             # compat pickle
#
# ~/anaconda2/envs/py3/lib/python3.5/site-packages/pandas/io/pickle.py in read_wrapper(func)
#      65                             compression=inferred_compression,
# ---> 66                             is_text=False)
#      67         try:
#
# ~/anaconda2/envs/py3/lib/python3.5/site-packages/pandas/io/common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     331             if is_path:
# --> 332                 f = gzip.open(path_or_buf, mode)
#     333             else:
#
# ~/anaconda2/envs/py3/lib/python3.5/gzip.py in open(filename, mode, compresslevel, encoding, errors, newline)
#      52     if isinstance(filename, (str, bytes)):
# ---> 53         binary_file = GzipFile(filename, gz_mode, compresslevel)
#      54     elif hasattr(filename, "read") or hasattr(filename, "write"):
#
# ~/anaconda2/envs/py3/lib/python3.5/gzip.py in __init__(self, filename, mode, compresslevel, fileobj, mtime)
#     162         if fileobj is None:
# --> 163             fileobj = self.myfileobj = builtins.open(filename, mode or 'rb')
#     164         if filename is None:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Data/train_lite10000.df.pkl.gz'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# ~/anaconda2/envs/py3/lib/python3.5/site-packages/pandas/io/pickle.py in read_pickle(path, compression)
#      93     try:
# ---> 94         return try_read(path)
#      95     except:
#
# ~/anaconda2/envs/py3/lib/python3.5/site-packages/pandas/io/pickle.py in try_read(path, encoding)
#      91                 return read_wrapper(
# ---> 92                     lambda f: pc.load(f, encoding=encoding, compat=True))
#      93     try:
#
# ~/anaconda2/envs/py3/lib/python3.5/site-packages/pandas/io/pickle.py in read_wrapper(func)
#      65                             compression=inferred_compression,
# ---> 66                             is_text=False)
#      67         try:
#
# ~/anaconda2/envs/py3/lib/python3.5/site-packages/pandas/io/common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     331             if is_path:
# --> 332                 f = gzip.open(path_or_buf, mode)
#     333             else:
#
# ~/anaconda2/envs/py3/lib/python3.5/gzip.py in open(filename, mode, compresslevel, encoding, errors, newline)
#      52     if isinstance(filename, (str, bytes)):
# ---> 53         binary_file = GzipFile(filename, gz_mode, compresslevel)
#      54     elif hasattr(filename, "read") or hasattr(filename, "write"):
#
# ~/anaconda2/envs/py3/lib/python3.5/gzip.py in __init__(self, filename, mode, compresslevel, fileobj, mtime)
#     162         if fileobj is None:
# --> 163             fileobj = self.myfileobj = builtins.open(filename, mode or 'rb')
#     164         if filename is None:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Data/train_lite10000.df.pkl.gz'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# ~/anaconda2/envs/py3/lib/python3.5/site-packages/pandas/io/pickle.py in try_read(path, encoding)
#      82         try:
# ---> 83             return read_wrapper(lambda f: pkl.load(f))
#      84         except Exception:
#
# ~/anaconda2/envs/py3/lib/python3.5/site-packages/pandas/io/pickle.py in read_wrapper(func)
#      65                             compression=inferred_compression,
# ---> 66                             is_text=False)
#      67         try:
#
# ~/anaconda2/envs/py3/lib/python3.5/site-packages/pandas/io/common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     331             if is_path:
# --> 332                 f = gzip.open(path_or_buf, mode)
#     333             else:
#
# ~/anaconda2/envs/py3/lib/python3.5/gzip.py in open(filename, mode, compresslevel, encoding, errors, newline)
#      52     if isinstance(filename, (str, bytes)):
# ---> 53         binary_file = GzipFile(filename, gz_mode, compresslevel)
#      54     elif hasattr(filename, "read") or hasattr(filename, "write"):
#
# ~/anaconda2/envs/py3/lib/python3.5/gzip.py in __init__(self, filename, mode, compresslevel, fileobj, mtime)
#     162         if fileobj is None:
# --> 163             fileobj = self.myfileobj = builtins.open(filename, mode or 'rb')
#     164         if filename is None:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Data/train_lite10000.df.pkl.gz'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# ~/anaconda2/envs/py3/lib/python3.5/site-packages/pandas/io/pickle.py in try_read(path, encoding)
#      87                 return read_wrapper(
# ---> 88                     lambda f: pc.load(f, encoding=encoding, compat=False))
#      89             # compat pickle
#
# ~/anaconda2/envs/py3/lib/python3.5/site-packages/pandas/io/pickle.py in read_wrapper(func)
#      65                             compression=inferred_compression,
# ---> 66                             is_text=False)
#      67         try:
#
# ~/anaconda2/envs/py3/lib/python3.5/site-packages/pandas/io/common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     331             if is_path:
# --> 332                 f = gzip.open(path_or_buf, mode)
#     333             else:
#
# ~/anaconda2/envs/py3/lib/python3.5/gzip.py in open(filename, mode, compresslevel, encoding, errors, newline)
#      52     if isinstance(filename, (str, bytes)):
# ---> 53         binary_file = GzipFile(filename, gz_mode, compresslevel)
#      54     elif hasattr(filename, "read") or hasattr(filename, "write"):
#
# ~/anaconda2/envs/py3/lib/python3.5/gzip.py in __init__(self, filename, mode, compresslevel, fileobj, mtime)
#     162         if fileobj is None:
# --> 163             fileobj = self.myfileobj = builtins.open(filename, mode or 'rb')
#     164         if filename is None:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Data/train_lite10000.df.pkl.gz'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-f13ff992b359> in <module>()
#       4     f = "Data/train_lite"+str(i)+".df.pkl.gz"
#       5     print("Starting ", f, i, i+1000, pretty_timedelta(since=t0))
# ----> 6     x = pd.read_pickle(f)
#       7     train_lite = pd.concat([train_lite, x])
#       8     print("Finished ", f, i, i+1000, pretty_timedelta(since=t0))
#
# ~/anaconda2/envs/py3/lib/python3.5/site-packages/pandas/io/pickle.py in read_pickle(path, compression)
#      95     except:
#      96         if PY3:
# ---> 97             return try_read(path, encoding='latin1')
#      98         raise
#      99
#
# ~/anaconda2/envs/py3/lib/python3.5/site-packages/pandas/io/pickle.py in try_read(path, encoding)
#      90             except:
#      91                 return read_wrapper(
# ---> 92                     lambda f: pc.load(f, encoding=encoding, compat=True))
#      93     try:
#      94         return try_read(path)
#
# ~/anaconda2/envs/py3/lib/python3.5/site-packages/pandas/io/pickle.py in read_wrapper(func)
#      64         f, fh = _get_handle(path, 'rb',
#      65                             compression=inferred_compression,
# ---> 66                             is_text=False)
#      67         try:
#      68             return func(f)
#
# ~/anaconda2/envs/py3/lib/python3.5/site-packages/pandas/io/common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     330             import gzip
#     331             if is_path:
# --> 332                 f = gzip.open(path_or_buf, mode)
#     333             else:
#     334                 f = gzip.GzipFile(fileobj=path_or_buf)
#
# ~/anaconda2/envs/py3/lib/python3.5/gzip.py in open(filename, mode, compresslevel, encoding, errors, newline)
#      51     gz_mode = mode.replace("t", "")
#      52     if isinstance(filename, (str, bytes)):
# ---> 53         binary_file = GzipFile(filename, gz_mode, compresslevel)
#      54     elif hasattr(filename, "read") or hasattr(filename, "write"):
#      55         binary_file = GzipFile(None, gz_mode, compresslevel, filename)
#
# ~/anaconda2/envs/py3/lib/python3.5/gzip.py in __init__(self, filename, mode, compresslevel, fileobj, mtime)
#     161             mode += 'b'
#     162         if fileobj is None:
# --> 163             fileobj = self.myfileobj = builtins.open(filename, mode or 'rb')
#     164         if filename is None:
#     165             filename = getattr(fileobj, 'name', '')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Data/train_lite10000.df.pkl.gz'

# %%
f = "Data/dev0.df.pkl.gz"
dev = pd.read_pickle(f)

# %%
t0 = time.time()
i = 1000
while True:
    f = "Data/dev"+str(i)+".df.pkl.gz"
    print("Starting ", f, i, i+1000, pretty_timedelta(since=t0))
    x = pd.read_pickle(f)
    dev = pd.concat([dev, x])
    print("Finished ", f, i, i+1000, pretty_timedelta(since=t0))
    i += 1000
    if i == 34000:
        i = 35000 # skip bad fi
# Out:
# Starting  Data/dev1000.df.pkl.gz 1000 2000 0:00:00
# Finished  Data/dev1000.df.pkl.gz 1000 2000 0:00:00
# Starting  Data/dev2000.df.pkl.gz 2000 3000 0:00:00
# Finished  Data/dev2000.df.pkl.gz 2000 3000 0:00:00
# Starting  Data/dev3000.df.pkl.gz 3000 4000 0:00:00
# Finished  Data/dev3000.df.pkl.gz 3000 4000 0:00:00
# Starting  Data/dev4000.df.pkl.gz 4000 5000 0:00:00
# Finished  Data/dev4000.df.pkl.gz 4000 5000 0:00:00
# Starting  Data/dev5000.df.pkl.gz 5000 6000 0:00:00
# Finished  Data/dev5000.df.pkl.gz 5000 6000 0:00:00
# Starting  Data/dev6000.df.pkl.gz 6000 7000 0:00:00
# Finished  Data/dev6000.df.pkl.gz 6000 7000 0:00:00
# Starting  Data/dev7000.df.pkl.gz 7000 8000 0:00:00
# Finished  Data/dev7000.df.pkl.gz 7000 8000 0:00:00
# Starting  Data/dev8000.df.pkl.gz 8000 9000 0:00:00
# Finished  Data/dev8000.df.pkl.gz 8000 9000 0:00:00
# Starting  Data/dev9000.df.pkl.gz 9000 10000 0:00:00
# Finished  Data/dev9000.df.pkl.gz 9000 10000 0:00:00
# Starting  Data/dev10000.df.pkl.gz 10000 11000 0:00:00
# Finished  Data/dev10000.df.pkl.gz 10000 11000 0:00:00
# Starting  Data/dev11000.df.pkl.gz 11000 12000 0:00:00
# Finished  Data/dev11000.df.pkl.gz 11000 12000 0:00:00
# Starting  Data/dev12000.df.pkl.gz 12000 13000 0:00:00
# Finished  Data/dev12000.df.pkl.gz 12000 13000 0:00:00
# Starting  Data/dev13000.df.pkl.gz 13000 14000 0:00:00
# Finished  Data/dev13000.df.pkl.gz 13000 14000 0:00:00
# Starting  Data/dev14000.df.pkl.gz 14000 15000 0:00:00
# Finished  Data/dev14000.df.pkl.gz 14000 15000 0:00:00
# Starting  Data/dev15000.df.pkl.gz 15000 16000 0:00:00
# Finished  Data/dev15000.df.pkl.gz 15000 16000 0:00:00
# Starting  Data/dev16000.df.pkl.gz 16000 17000 0:00:00
# Finished  Data/dev16000.df.pkl.gz 16000 17000 0:00:00
# Starting  Data/dev17000.df.pkl.gz 17000 18000 0:00:00
# Finished  Data/dev17000.df.pkl.gz 17000 18000 0:00:00
# Starting  Data/dev18000.df.pkl.gz 18000 19000 0:00:00
# Finished  Data/dev18000.df.pkl.gz 18000 19000 0:00:00
# Starting  Data/dev19000.df.pkl.gz 19000 20000 0:00:00
# Finished  Data/dev19000.df.pkl.gz 19000 20000 0:00:00
# Starting  Data/dev20000.df.pkl.gz 20000 21000 0:00:00
# Finished  Data/dev20000.df.pkl.gz 20000 21000 0:00:00
# Starting  Data/dev21000.df.pkl.gz 21000 22000 0:00:00
# Finished  Data/dev21000.df.pkl.gz 21000 22000 0:00:00
# Starting  Data/dev22000.df.pkl.gz 22000 23000 0:00:00
# Finished  Data/dev22000.df.pkl.gz 22000 23000 0:00:00
# Starting  Data/dev23000.df.pkl.gz 23000 24000 0:00:00
# Finished  Data/dev23000.df.pkl.gz 23000 24000 0:00:00
# Starting  Data/dev24000.df.pkl.gz 24000 25000 0:00:00
# Finished  Data/dev24000.df.pkl.gz 24000 25000 0:00:00
# Starting  Data/dev25000.df.pkl.gz 25000 26000 0:00:00
# Finished  Data/dev25000.df.pkl.gz 25000 26000 0:00:00
# Starting  Data/dev26000.df.pkl.gz 26000 27000 0:00:00
# Finished  Data/dev26000.df.pkl.gz 26000 27000 0:00:00
# Starting  Data/dev27000.df.pkl.gz 27000 28000 0:00:00
# Finished  Data/dev27000.df.pkl.gz 27000 28000 0:00:00
# Starting  Data/dev28000.df.pkl.gz 28000 29000 0:00:00
# Finished  Data/dev28000.df.pkl.gz 28000 29000 0:00:00
# Starting  Data/dev29000.df.pkl.gz 29000 30000 0:00:00
# Finished  Data/dev29000.df.pkl.gz 29000 30000 0:00:00
# Starting  Data/dev30000.df.pkl.gz 30000 31000 0:00:00
# Finished  Data/dev30000.df.pkl.gz 30000 31000 0:00:00
# Starting  Data/dev31000.df.pkl.gz 31000 32000 0:00:00
# Finished  Data/dev31000.df.pkl.gz 31000 32000 0:00:00
# Starting  Data/dev32000.df.pkl.gz 32000 33000 0:00:00
# Finished  Data/dev32000.df.pkl.gz 32000 33000 0:00:00
# Starting  Data/dev33000.df.pkl.gz 33000 34000 0:00:00
# Finished  Data/dev33000.df.pkl.gz 33000 34000 0:00:00
# Starting  Data/dev34000.df.pkl.gz 34000 35000 0:00:00
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/anaconda2/envs/py3/lib/python3.5/site-packages/pandas/io/pickle.py in try_read(path, encoding)
#      82         try:
# ---> 83             return read_wrapper(lambda f: pkl.load(f))
#      84         except Exception:
#
# ~/anaconda2/envs/py3/lib/python3.5/site-packages/pandas/io/pickle.py in read_wrapper(func)
#      65                             compression=inferred_compression,
# ---> 66                             is_text=False)
#      67         try:
#
# ~/anaconda2/envs/py3/lib/python3.5/site-packages/pandas/io/common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     331             if is_path:
# --> 332                 f = gzip.open(path_or_buf, mode)
#     333             else:
#
# ~/anaconda2/envs/py3/lib/python3.5/gzip.py in open(filename, mode, compresslevel, encoding, errors, newline)
#      52     if isinstance(filename, (str, bytes)):
# ---> 53         binary_file = GzipFile(filename, gz_mode, compresslevel)
#      54     elif hasattr(filename, "read") or hasattr(filename, "write"):
#
# ~/anaconda2/envs/py3/lib/python3.5/gzip.py in __init__(self, filename, mode, compresslevel, fileobj, mtime)
#     162         if fileobj is None:
# --> 163             fileobj = self.myfileobj = builtins.open(filename, mode or 'rb')
#     164         if filename is None:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Data/dev34000.df.pkl.gz'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# ~/anaconda2/envs/py3/lib/python3.5/site-packages/pandas/io/pickle.py in try_read(path, encoding)
#      87                 return read_wrapper(
# ---> 88                     lambda f: pc.load(f, encoding=encoding, compat=False))
#      89             # compat pickle
#
# ~/anaconda2/envs/py3/lib/python3.5/site-packages/pandas/io/pickle.py in read_wrapper(func)
#      65                             compression=inferred_compression,
# ---> 66                             is_text=False)
#      67         try:
#
# ~/anaconda2/envs/py3/lib/python3.5/site-packages/pandas/io/common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     331             if is_path:
# --> 332                 f = gzip.open(path_or_buf, mode)
#     333             else:
#
# ~/anaconda2/envs/py3/lib/python3.5/gzip.py in open(filename, mode, compresslevel, encoding, errors, newline)
#      52     if isinstance(filename, (str, bytes)):
# ---> 53         binary_file = GzipFile(filename, gz_mode, compresslevel)
#      54     elif hasattr(filename, "read") or hasattr(filename, "write"):
#
# ~/anaconda2/envs/py3/lib/python3.5/gzip.py in __init__(self, filename, mode, compresslevel, fileobj, mtime)
#     162         if fileobj is None:
# --> 163             fileobj = self.myfileobj = builtins.open(filename, mode or 'rb')
#     164         if filename is None:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Data/dev34000.df.pkl.gz'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# ~/anaconda2/envs/py3/lib/python3.5/site-packages/pandas/io/pickle.py in read_pickle(path, compression)
#      93     try:
# ---> 94         return try_read(path)
#      95     except:
#
# ~/anaconda2/envs/py3/lib/python3.5/site-packages/pandas/io/pickle.py in try_read(path, encoding)
#      91                 return read_wrapper(
# ---> 92                     lambda f: pc.load(f, encoding=encoding, compat=True))
#      93     try:
#
# ~/anaconda2/envs/py3/lib/python3.5/site-packages/pandas/io/pickle.py in read_wrapper(func)
#      65                             compression=inferred_compression,
# ---> 66                             is_text=False)
#      67         try:
#
# ~/anaconda2/envs/py3/lib/python3.5/site-packages/pandas/io/common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     331             if is_path:
# --> 332                 f = gzip.open(path_or_buf, mode)
#     333             else:
#
# ~/anaconda2/envs/py3/lib/python3.5/gzip.py in open(filename, mode, compresslevel, encoding, errors, newline)
#      52     if isinstance(filename, (str, bytes)):
# ---> 53         binary_file = GzipFile(filename, gz_mode, compresslevel)
#      54     elif hasattr(filename, "read") or hasattr(filename, "write"):
#
# ~/anaconda2/envs/py3/lib/python3.5/gzip.py in __init__(self, filename, mode, compresslevel, fileobj, mtime)
#     162         if fileobj is None:
# --> 163             fileobj = self.myfileobj = builtins.open(filename, mode or 'rb')
#     164         if filename is None:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Data/dev34000.df.pkl.gz'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# ~/anaconda2/envs/py3/lib/python3.5/site-packages/pandas/io/pickle.py in try_read(path, encoding)
#      82         try:
# ---> 83             return read_wrapper(lambda f: pkl.load(f))
#      84         except Exception:
#
# ~/anaconda2/envs/py3/lib/python3.5/site-packages/pandas/io/pickle.py in read_wrapper(func)
#      65                             compression=inferred_compression,
# ---> 66                             is_text=False)
#      67         try:
#
# ~/anaconda2/envs/py3/lib/python3.5/site-packages/pandas/io/common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     331             if is_path:
# --> 332                 f = gzip.open(path_or_buf, mode)
#     333             else:
#
# ~/anaconda2/envs/py3/lib/python3.5/gzip.py in open(filename, mode, compresslevel, encoding, errors, newline)
#      52     if isinstance(filename, (str, bytes)):
# ---> 53         binary_file = GzipFile(filename, gz_mode, compresslevel)
#      54     elif hasattr(filename, "read") or hasattr(filename, "write"):
#
# ~/anaconda2/envs/py3/lib/python3.5/gzip.py in __init__(self, filename, mode, compresslevel, fileobj, mtime)
#     162         if fileobj is None:
# --> 163             fileobj = self.myfileobj = builtins.open(filename, mode or 'rb')
#     164         if filename is None:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Data/dev34000.df.pkl.gz'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# ~/anaconda2/envs/py3/lib/python3.5/site-packages/pandas/io/pickle.py in try_read(path, encoding)
#      87                 return read_wrapper(
# ---> 88                     lambda f: pc.load(f, encoding=encoding, compat=False))
#      89             # compat pickle
#
# ~/anaconda2/envs/py3/lib/python3.5/site-packages/pandas/io/pickle.py in read_wrapper(func)
#      65                             compression=inferred_compression,
# ---> 66                             is_text=False)
#      67         try:
#
# ~/anaconda2/envs/py3/lib/python3.5/site-packages/pandas/io/common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     331             if is_path:
# --> 332                 f = gzip.open(path_or_buf, mode)
#     333             else:
#
# ~/anaconda2/envs/py3/lib/python3.5/gzip.py in open(filename, mode, compresslevel, encoding, errors, newline)
#      52     if isinstance(filename, (str, bytes)):
# ---> 53         binary_file = GzipFile(filename, gz_mode, compresslevel)
#      54     elif hasattr(filename, "read") or hasattr(filename, "write"):
#
# ~/anaconda2/envs/py3/lib/python3.5/gzip.py in __init__(self, filename, mode, compresslevel, fileobj, mtime)
#     162         if fileobj is None:
# --> 163             fileobj = self.myfileobj = builtins.open(filename, mode or 'rb')
#     164         if filename is None:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Data/dev34000.df.pkl.gz'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-17-ccc35a38f329> in <module>()
#       4     f = "Data/dev"+str(i)+".df.pkl.gz"
#       5     print("Starting ", f, i, i+1000, pretty_timedelta(since=t0))
# ----> 6     x = pd.read_pickle(f)
#       7     dev = pd.concat([dev, x])
#       8     print("Finished ", f, i, i+1000, pretty_timedelta(since=t0))
#
# ~/anaconda2/envs/py3/lib/python3.5/site-packages/pandas/io/pickle.py in read_pickle(path, compression)
#      95     except:
#      96         if PY3:
# ---> 97             return try_read(path, encoding='latin1')
#      98         raise
#      99
#
# ~/anaconda2/envs/py3/lib/python3.5/site-packages/pandas/io/pickle.py in try_read(path, encoding)
#      90             except:
#      91                 return read_wrapper(
# ---> 92                     lambda f: pc.load(f, encoding=encoding, compat=True))
#      93     try:
#      94         return try_read(path)
#
# ~/anaconda2/envs/py3/lib/python3.5/site-packages/pandas/io/pickle.py in read_wrapper(func)
#      64         f, fh = _get_handle(path, 'rb',
#      65                             compression=inferred_compression,
# ---> 66                             is_text=False)
#      67         try:
#      68             return func(f)
#
# ~/anaconda2/envs/py3/lib/python3.5/site-packages/pandas/io/common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     330             import gzip
#     331             if is_path:
# --> 332                 f = gzip.open(path_or_buf, mode)
#     333             else:
#     334                 f = gzip.GzipFile(fileobj=path_or_buf)
#
# ~/anaconda2/envs/py3/lib/python3.5/gzip.py in open(filename, mode, compresslevel, encoding, errors, newline)
#      51     gz_mode = mode.replace("t", "")
#      52     if isinstance(filename, (str, bytes)):
# ---> 53         binary_file = GzipFile(filename, gz_mode, compresslevel)
#      54     elif hasattr(filename, "read") or hasattr(filename, "write"):
#      55         binary_file = GzipFile(None, gz_mode, compresslevel, filename)
#
# ~/anaconda2/envs/py3/lib/python3.5/gzip.py in __init__(self, filename, mode, compresslevel, fileobj, mtime)
#     161             mode += 'b'
#     162         if fileobj is None:
# --> 163             fileobj = self.myfileobj = builtins.open(filename, mode or 'rb')
#     164         if filename is None:
#     165             filename = getattr(fileobj, 'name', '')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Data/dev34000.df.pkl.gz'
